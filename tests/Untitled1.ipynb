# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
q = 0.9
n = 50

v = []
for i in range(n):
    v += [(q ** (i+1) - 1) / (q-1)]
    
plt.figure(figsize=(16,9))
plt.scatter(range(n), v)
plt.axhline(y=1/(1-q))
