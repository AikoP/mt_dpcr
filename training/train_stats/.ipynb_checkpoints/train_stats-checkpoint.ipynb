# %% [markdown]
# ### Imports & Preparation

# %%
import sys
sys.path.insert(1, '../../')  # to load from any submodule in the repo

import torch
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from utils import plotUtils

# %% [markdown]
# ### Checkpoint Loading

# %%
#checkpoin_hpc = torch.load('../../hpc/results/aaa/bbb/ccc.t7')
#checkpoint_local = torch.load('../../training/checkpoints/aaa/bbb/ccc.t7')

checkpoint_corrector = torch.load('../../training/checkpoints/corrector_01single_cube_cnet_global_mish_radam_sd/2020-11-17_154400/corrector_checkpoints.t7')
checkpoint_detector = torch.load('../../training/checkpoints/detector_single_cube_cnet_global_mish_radam_sd/2020-11-16_151940/detector_checkpoints.t7')
checkpoint_predictor = torch.load('../../training/checkpoints/predictor_single_cube_cnet_mish_radam_sd/2020-11-15_131355/predictor_checkpoints.t7')

checkpoint_detector = torch.load('../../charts/detector_checkpoints_overfitted.t7')

# %%
plotUtils.plotPredictor(checkpoint_predictor)
# Out:
# train time:  2.9359705989228355 h

# %%
plotUtils.plotPredictor(checkpoint_corrector, y_max=0.0002)
# Out:
# train time:  2.58664596815904 h

# %%
plotUtils.plotDetector(checkpoint_detector, mode='loss', y_max = 0.8, loc='upper left')
# Out:
# train time:  3.265999031530486 h

# %%
plotUtils.plotLearningRate(checkpoint_predictor, y_max=0.0001)
